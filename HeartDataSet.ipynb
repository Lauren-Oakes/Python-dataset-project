# %%
# Importing the holy trinity of data science.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# getting seaborn online to give our graphics a kick.
import seaborn as sns
sns.set()

# %%
heart_df = pd.read_csv("Framingham Dataset.csv")

# %% [raw]
# heart_df

# %%
heart_df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...         0    8766    6438      6438     6438      8766
# 1         0  ...         0    8766    6438      6438     6438      8766
# 2         0  ...         0    8766    8766      8766     8766      8766
# 3         0  ...         0    8766    8766      8766     8766      8766
# 4         0  ...         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP  CHOLmmol/L
# 0     6438     8766     8766    5.042669
# ...

# %%
heart_df.tail()
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 11622  9998212    1    173.0   46  126.0   82.0         0      0.0  19.17
# 11623  9998212    1    153.0   52  143.0   89.0         0      0.0  25.74
# 11624  9999312    2    196.0   39  133.0   86.0         1     30.0  20.91
# 11625  9999312    2    240.0   46  138.0   79.0         1     20.0  26.39
# 11626  9999312    2      NaN   50  147.0   96.0         1     10.0  24.19
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 11622         0  ...         1    8766    8766      8766     8766      8766
# 11623         0  ...         1    8766    8766      8766     8766      8766
# 11624         0  ...         1    8766    8766      8766     8766      8766
# 11625         0  ...         1    8766    8766      8766     8766      8766
# 11626         0  ...         1    8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP  CHOLmmol/L
# ...

# %%
heart_df.describe()
# Out:
#              RANDID           SEX       TOTCHOL           AGE         SYSBP  \
# count  1.162700e+04  11627.000000  11218.000000  11627.000000  11627.000000
# mean   5.004741e+06      1.568074    241.162418     54.792810    136.324116
# std    2.900877e+06      0.495366     45.368030      9.564299     22.798625
# min    2.448000e+03      1.000000    107.000000     32.000000     83.500000
# 25%    2.474378e+06      1.000000    210.000000     48.000000    120.000000
# 50%    5.006008e+06      2.000000    238.000000     54.000000    132.000000
# 75%    7.472730e+06      2.000000    268.000000     62.000000    149.000000
# max    9.999312e+06      2.000000    696.000000     81.000000    295.000000
#
#               DIABP      CURSMOKE       CIGPDAY           BMI      DIABETES  \
# count  11627.000000  11627.000000  11548.000000  11575.000000  11627.000000
# mean      83.037757      0.432528      8.250346     25.877349      0.045584
# ...

# %%
len(heart_df)
# Out:
# 11627

# %%
heart_df.keys()
# Out:
# Index(['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
#        'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'educ',
#        'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD',
#        'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD',
#        'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD',
#        'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP', 'CHOLmmol/L'],
#       dtype='object')

# %%
heart_df.columns
# Out:
# Index(['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
#        'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'educ',
#        'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD',
#        'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD',
#        'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD',
#        'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP'],
#       dtype='object')

# %%
heart_df['CHOLmmol/L'] = heart_df['TOTCHOL'] / 38.67

# %%
heart_df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...         0    8766    6438      6438     6438      8766
# 1         0  ...         0    8766    6438      6438     6438      8766
# 2         0  ...         0    8766    8766      8766     8766      8766
# 3         0  ...         0    8766    8766      8766     8766      8766
# 4         0  ...         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP  CHOLmmol/L
# 0     6438     8766     8766    5.042669
# ...

# %%
heart_df.tail()
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 11622  9998212    1    173.0   46  126.0   82.0         0      0.0  19.17
# 11623  9998212    1    153.0   52  143.0   89.0         0      0.0  25.74
# 11624  9999312    2    196.0   39  133.0   86.0         1     30.0  20.91
# 11625  9999312    2    240.0   46  138.0   79.0         1     20.0  26.39
# 11626  9999312    2      NaN   50  147.0   96.0         1     10.0  24.19
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 11622         0  ...         1    8766    8766      8766     8766      8766
# 11623         0  ...         1    8766    8766      8766     8766      8766
# 11624         0  ...         1    8766    8766      8766     8766      8766
# 11625         0  ...         1    8766    8766      8766     8766      8766
# 11626         0  ...         1    8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP  CHOLmmol/L
# ...

# %%
heart_df[(heart_df['CIGPDAY'] == 0)&(heart_df['PREVCHD'] == 0)]
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1         2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3         6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# ...        ...  ...      ...  ...    ...    ...       ...      ...    ...
# 11619  9995546    2    269.0   52  133.5   83.0         0      0.0  21.47
# 11620  9995546    2    265.0   58  140.0   83.0         0      0.0  22.55
# 11621  9998212    1    185.0   40  141.0   98.0         0      0.0  25.60
# 11622  9998212    1    173.0   46  126.0   82.0         0      0.0  19.17
# 11623  9998212    1    153.0   52  143.0   89.0         0      0.0  25.74
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# ...

# %%
heart_df.hist('CHOLmmol/L')
# Out:
# array([[<Axes: title={'center': 'CHOLmmol/L'}>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

fig.suptitle('Correlation between Cholesterol levels and BMI')

heart_df.plot.scatter(x = 'CHOLmmol/L', y = 'AGE',s=1, c='green', ax=axes[0,0])
heart_df.plot.scatter(x = 'CHOLmmol/L', y = 'AGE', ax=axes[1,0])
heart_df.plot.scatter(x = 'CHOLmmol/L', y = 'AGE',s=1, c='black', ax=axes[0,1])
heart_df.plot.scatter(x = 'CHOLmmol/L', y = 'AGE', ax=axes[1,1])
# Out:
# <Axes: xlabel='CHOLmmol/L', ylabel='AGE'>
